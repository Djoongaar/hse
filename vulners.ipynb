# %%
import pandas as pd

# %%
df = pd.read_csv("vulners.csv", sep=";")
df[df['is_detected']].head(100)
# Out:
#                software version  is_detected            cve_list  \
# 3                 nginx  1.14.0         True  ['CVE-2018-16843']
# 4                 nginx  1.14.0         True  ['CVE-2018-16844']
# 5    Apache HTTP Server  2.4.29         True  ['CVE-2021-40438']
# 6    Apache HTTP Server  2.4.29         True  ['CVE-2021-41773']
# 7    Apache HTTP Server  2.4.29         True  ['CVE-2021-41773']
# ..                  ...     ...          ...                 ...
# 98   Apache HTTP Server  2.4.29         True  ['CVE-2018-17199']
# 99   Apache HTTP Server  2.4.29         True   ['CVE-2019-0196']
# 100  Apache HTTP Server  2.4.29         True   ['CVE-2019-0211']
# 101  Apache HTTP Server  2.4.29         True   ['CVE-2019-0217']
# 102  Apache HTTP Server  2.4.29         True   ['CVE-2019-0220']
#
#                                                   href  \
# 3    https://www.prio-n.com/kb/vulnerability/CVE-20...
# 4    https://www.prio-n.com/kb/vulnerability/CVE-20...
# ...

# %%
ls -l
# Out:
# total 137060
# -rwxrwxr-x 1 evgeny evgeny      7181 Mar 19 22:43 analyzer.py*
# -rw-rw-r-- 1 evgeny evgeny     12767 Feb 16 17:21 events.json
# -rw-rw-r-- 1 evgeny evgeny   4234490 Dec 11 12:56 funnel.csv
# -rw-rw-r-- 1 evgeny evgeny     48950 Mar 18 21:39 invoice-42369643.html
# -rw-rw-r-- 1 evgeny evgeny     34506 Mar 15 11:47 protected_archive.zip
# -rw-rw-r-- 1 evgeny evgeny   6621888 Dec  7 17:29 purchase_log.txt
# drwxrwxr-x 2 evgeny evgeny      4096 Jan 24 14:49 __pycache__/
# -rw-rw-r-- 1 evgeny evgeny      2097 Mar 18 21:39 report.csv
# -rw-rw-r-- 1 evgeny evgeny     17779 Mar 18 21:39 report.json
# -rw-rw-r-- 1 evgeny evgeny       908 Mar 15 18:08 requirements.txt
# -rw-rw-r-- 1 evgeny evgeny      2259 Mar 15 11:34 result.csv
# -rw-rw-r-- 1 evgeny evgeny     23509 Feb 16 17:47 sharaev_evgeny_hw10.ipynb
# -rw-rw-r-- 1 evgeny evgeny      5978 Nov 23 12:49 sharaev_evgeny_hw1.ipynb
# -rw-rw-r-- 1 evgeny evgeny      6022 Nov 23 12:47 sharaev_evgeny_hw1_part2.ipynb
# ...
